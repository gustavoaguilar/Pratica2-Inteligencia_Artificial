# %% [markdown]
# # Prática de Aprendizado Supervisionado

# %% [markdown]
# **Importando bibliotecas e funções**

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from scipy.io.arff import loadarff
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
import time
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# **Lendo o arquivo**

# %%
def leitura(dataset, nome):

    # Carrega o .arff
    raw_data = loadarff('Data/%s/%s.arff' % (dataset, nome))
    # Transforma o .arff em um Pandas Dataframe
    return pd.DataFrame(raw_data[0])
    # Imprime o Dataframe com suas colunas

# %% [markdown]
# **Separando em Conjunto de Treino e Teste**

# %%
# Com o iloc voce retira as linhas e colunas que quiser do Dataframe, no caso aqui sem as classes
def treinoTeste(df):

    X = df.iloc[:, 0:-1].values

    # Aqui salvamos apenas as classes agora
    y = df['class']
    # Substituimos os valores binários por inteiro
    bow = []
    int_value = 0
    y_aux = []
    for i in y:
      if i in bow:
        y_aux.append(int_value)
      else:
        bow.append(i)
        int_value += 1
        y_aux.append(int_value)
    # Novo y
    y = y_aux
    
    return train_test_split(X,y,test_size=0.2,random_state=327)

# %% [markdown]
# **Padronizando os dados com Técnicas de Normalização**

# %%
def normalizar(X_train, X_test, selectedNormalization):

    if selectedNormalization == 0:
        return X_train, X_test
    if selectedNormalization == 1:
        scaler = preprocessing.MinMaxScaler()
    if selectedNormalization == 2:
        scaler = preprocessing.StandardScaler()
    if selectedNormalization == 3:
        scaler = preprocessing.MaxAbsScaler()
    if selectedNormalization == 4:
        scaler = preprocessing.RobustScaler()

    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    
    return X_train, X_test

# %% [markdown]
# **Treinando os Classificadores**

# %%
def treinarClassificadores(classificador, X_train, X_test, y_train, y_test):
        
    cls = classificador
    cls.fit(X_train, y_train)
    t = time.time()
    aux = classificador.predict(X_test)
    f1score   = f1_score(y_test, aux, average = 'macro')
    precision = precision_score(y_test, aux, average = 'macro')
    recall    = recall_score(y_test, aux, average = 'macro')
    acc_train = classificador.score(X_train, y_train)
    acc_test  = classificador.score(X_test, y_test)
    tempoExe  = time.time() - t
        
    return acc_train, acc_test, f1score, precision, recall, tempoExe

# %% [markdown]
# **Testando o Conjunto de Teste**

# %%
def grid(dataset):
    
    normDic = {'0': 'não aplicado', '1': 'MinMaxScaler', '2': 'StandardScaler',
               '3': 'MaxAbsScaler', '4': 'RobustScaler'}
    extratores = ['AutoColorCorrelogram', 'FCTH', 'Gabor', 'GCH', 'LBP', 'LCH', 
                  'Moments', 'ReferenceColorSimilarity']
    nomes = ['Extrator', 'Normalizador', 'Classificador', 'Tempo', 'Acurácia', 'Precisão', 'Recall', 'F1 Score']
    classificadores = [(GaussianNB(), 'Gaussian Naive Bayes'), (LogisticRegression(), 'Logistic Regression'), 
                       (DecisionTreeClassifier(), 'Decision Tree'), (KNeighborsClassifier(n_neighbors = 3), 'KNN'),
                       (LinearDiscriminantAnalysis(), 'Linear Discriminant Analysis'), (SVC(), 'SVM'), 
                       (RandomForestClassifier(random_state=42), 'Random Forest'), (MLPClassifier(alpha=1), 'MLP')]
    
    analise = []
    
    for extrator in extratores:
        
        df = leitura(dataset, extrator)
        
        for norm in range(5):
            X_train, X_test, y_train, y_test = treinoTeste(df)
            X_train, X_test = normalizar(X_train, X_test, norm)
            
            for cls, nome in classificadores:
                dados = treinarClassificadores(cls, X_train, X_test, y_train, y_test)
                acc_train, acc_test, f1score, precision, recall, tempoExe = dados
            
                resultados = [extrator, normDic[str(norm)], nome, tempoExe, 
                              acc_test, precision, recall, f1score]
            
                analise.append(resultados)
            
    return pd.DataFrame(analise, columns=nomes).set_index(['Extrator', 'Normalizador', 'Classificador'])

# %%
df = leitura('Malaria-Cell', 'FCTH')
X_train, X_test, y_train, y_test = treinoTeste(df)
X_train, X_test = normalizar(X_train, X_test, 1)
dados = treinarClassificadores(GaussianNB(), X_train, X_test, y_train, y_test)
acc_train, acc_test, f1score, precision, recall, tempoExe = dados
resultados = ['FCTH', 'MinMaxScaler', 'nome', tempoExe, 
                              acc_test, precision, recall, f1score]
resultados
# Out:
# ['FCTH',
#  'MinMaxScaler',
#  'nome',
#  0.3478817939758301,
#  0.5400943396226415,
#  0.6262803092067518,
#  0.5440514156580938,
#  0.4532288463446086]

# %%
def selecao(resultados):
    
    perf = ((resultados['Acurácia'] + resultados['F1 Score']) / 2) / resultados['Tempo']
    acc  = (resultados['Acurácia'] + resultados['F1 Score']) / 2
    
    return pd.DataFrame(resultados.loc[np.argmax(perf), :]).T , pd.DataFrame(resultados.loc[np.argmax(acc), :]).T

# %%
resultados = grid('Malaria-Cell')

# %%
resultados
# Out:
#                                                                            Tempo  \
# Extrator                 Normalizador   Classificador
# AutoColorCorrelogram     não aplicado   Gaussian Naive Bayes            1.241665
#                                         Logistic Regression             0.113908
#                                         Decision Tree                   0.180844
#                                         KNN                           555.105502
#                                         Linear Discriminant Analysis    0.082135
#                                         SVM                           521.662776
#                                         Random Forest                   0.181783
#                                         MLP                             0.148893
#                          MinMaxScaler   Gaussian Naive Bayes            0.623256
#                                         Logistic Regression             0.054749
#                                         Decision Tree                   0.087913
#                                         KNN                           155.425773
#                                         Linear Discriminant Analysis    0.054885
#                                         SVM                           515.699564
#                                         Random Forest                   0.177713
#                                         MLP                             0.145565
#                          StandardScaler Gaussian Naive Bayes            0.656589
#                                         Logistic Regression             0.061374
#                                         Decision Tree                   0.087809
#                                         KNN                           739.404620
#                                         Linear Discriminant Analysis    0.054533
#                                         SVM                           415.636523
#                                         Random Forest                   0.186087
#                                         MLP                             0.151175
#                          MaxAbsScaler   Gaussian Naive Bayes            0.637148
#                                         Logistic Regression             0.058570
#                                         Decision Tree                   0.085332
#                                         KNN                           339.196182
#                                         Linear Discriminant Analysis    0.055438
#                                         SVM                           519.884832
# ...                                                                          ...
# ReferenceColorSimilarity MinMaxScaler   Decision Tree                   0.026186
#                                         KNN                             5.355303
#                                         Linear Discriminant Analysis    0.028143
#                                         SVM                            63.972426
#                                         Random Forest                   0.105063
#                                         MLP                             0.047046
#                          StandardScaler Gaussian Naive Bayes            0.054647
#                                         Logistic Regression             0.019111
#                                         Decision Tree                   0.026643
#                                         KNN                             5.343172
#                                         Linear Discriminant Analysis    0.022890
#                                         SVM                            52.710148
#                                         Random Forest                   0.094956
#                                         MLP                             0.047541
#                          MaxAbsScaler   Gaussian Naive Bayes            0.058383
#                                         Logistic Regression             0.029525
#                                         Decision Tree                   0.026323
#                                         KNN                             4.568727
#                                         Linear Discriminant Analysis    0.019047
#                                         SVM                            67.178066
#                                         Random Forest                   0.093132
#                                         MLP                             0.042323
#                          RobustScaler   Gaussian Naive Bayes            0.055871
#                                         Logistic Regression             0.019429
#                                         Decision Tree                   0.026392
#                                         KNN                             5.087428
#                                         Linear Discriminant Analysis    0.018996
#                                         SVM                            54.639582
#                                         Random Forest                   0.090995
#                                         MLP                             0.045410
#
#                                                                       Acurácia  \
# Extrator                 Normalizador   Classificador
# AutoColorCorrelogram     não aplicado   Gaussian Naive Bayes          0.628447
#                                         Logistic Regression           0.698295
#                                         Decision Tree                 0.938135
#                                         KNN                           0.722605
#                                         Linear Discriminant Analysis  0.839985
#                                         SVM                           0.642598
#                                         Random Forest                 0.955552
#                                         MLP                           0.664369
#                          MinMaxScaler   Gaussian Naive Bayes          0.598149
#                                         Logistic Regression           0.728592
#                                         Decision Tree                 0.932692
#                                         KNN                           0.718977
#                                         Linear Discriminant Analysis  0.839985
#                                         SVM                           0.646226
#                                         Random Forest                 0.955552
#                                         MLP                           0.672533
#                          StandardScaler Gaussian Naive Bayes          0.578012
#                                         Logistic Regression           0.852866
#                                         Decision Tree                 0.932692
#                                         KNN                           0.823657
#                                         Linear Discriminant Analysis  0.839985
#                                         SVM                           0.841618
#                                         Random Forest                 0.956821
#                                         MLP                           0.913643
#                          MaxAbsScaler   Gaussian Naive Bayes          0.598149
#                                         Logistic Regression           0.728592
#                                         Decision Tree                 0.934325
#                                         KNN                           0.726415
#                                         Linear Discriminant Analysis  0.839985
#                                         SVM                           0.643505
# ...                                                                        ...
# ReferenceColorSimilarity MinMaxScaler   Decision Tree                 0.652032
#                                         KNN                           0.699746
#                                         Linear Discriminant Analysis  0.735849
#                                         SVM                           0.668360
#                                         Random Forest                 0.704282
#                                         MLP                           0.672351
#                          StandardScaler Gaussian Naive Bayes          0.622279
#                                         Logistic Regression           0.772678
#                                         Decision Tree                 0.656386
#                                         KNN                           0.694848
#                                         Linear Discriminant Analysis  0.735849
#                                         SVM                           0.751996
#                                         Random Forest                 0.705914
#                                         MLP                           0.831277
#                          MaxAbsScaler   Gaussian Naive Bayes          0.622279
#                                         Logistic Regression           0.658563
#                                         Decision Tree                 0.660559
#                                         KNN                           0.691038
#                                         Linear Discriminant Analysis  0.735849
#                                         SVM                           0.661829
#                                         Random Forest                 0.707547
#                                         MLP                           0.647678
#                          RobustScaler   Gaussian Naive Bayes          0.622279
#                                         Logistic Regression           0.757801
#                                         Decision Tree                 0.652395
#                                         KNN                           0.693396
#                                         Linear Discriminant Analysis  0.735849
#                                         SVM                           0.731495
#                                         Random Forest                 0.705914
#                                         MLP                           0.797533
#
#                                                                       Precisão  \
# Extrator                 Normalizador   Classificador
# AutoColorCorrelogram     não aplicado   Gaussian Naive Bayes          0.768363
#                                         Logistic Regression           0.699702
#                                         Decision Tree                 0.938168
#                                         KNN                           0.722590
#                                         Linear Discriminant Analysis  0.847375
#                                         SVM                           0.652368
#                                         Random Forest                 0.955576
#                                         MLP                           0.665503
#                          MinMaxScaler   Gaussian Naive Bayes          0.754574
#                                         Logistic Regression           0.730230
#                                         Decision Tree                 0.932771
#                                         KNN                           0.719231
#                                         Linear Discriminant Analysis  0.847375
#                                         SVM                           0.654871
#                                         Random Forest                 0.955576
#                                         MLP                           0.675467
#                          StandardScaler Gaussian Naive Bayes          0.750890
#                                         Logistic Regression           0.868292
#                                         Decision Tree                 0.932738
#                                         KNN                           0.829498
#                                         Linear Discriminant Analysis  0.847375
#                                         SVM                           0.870868
#                                         Random Forest                 0.956817
#                                         MLP                           0.919835
#                          MaxAbsScaler   Gaussian Naive Bayes          0.754574
#                                         Logistic Regression           0.730230
#                                         Decision Tree                 0.934383
#                                         KNN                           0.726680
#                                         Linear Discriminant Analysis  0.847375
#                                         SVM                           0.653181
# ...                                                                        ...
# ReferenceColorSimilarity MinMaxScaler   Decision Tree                 0.652215
#                                         KNN                           0.699766
#                                         Linear Discriminant Analysis  0.739196
#                                         SVM                           0.671770
#                                         Random Forest                 0.705271
#                                         MLP                           0.672563
#                          StandardScaler Gaussian Naive Bayes          0.622258
#                                         Logistic Regression           0.779335
#                                         Decision Tree                 0.656494
#                                         KNN                           0.694834
#                                         Linear Discriminant Analysis  0.739196
#                                         SVM                           0.755085
#                                         Random Forest                 0.706883
#                                         MLP                           0.833071
#                          MaxAbsScaler   Gaussian Naive Bayes          0.622258
#                                         Logistic Regression           0.662343
#                                         Decision Tree                 0.660708
#                                         KNN                           0.691022
#                                         Linear Discriminant Analysis  0.739196
#                                         SVM                           0.665414
#                                         Random Forest                 0.708394
#                                         MLP                           0.650563
#                          RobustScaler   Gaussian Naive Bayes          0.622258
#                                         Logistic Regression           0.766455
#                                         Decision Tree                 0.652691
#                                         KNN                           0.693385
#                                         Linear Discriminant Analysis  0.739196
#                                         SVM                           0.734167
#                                         Random Forest                 0.706883
#                                         MLP                           0.799932
#
#                                                                         Recall  \
# Extrator                 Normalizador   Classificador
# AutoColorCorrelogram     não aplicado   Gaussian Naive Bayes          0.631952
#                                         Logistic Regression           0.698669
#                                         Decision Tree                 0.938099
#                                         KNN                           0.722538
#                                         Linear Discriminant Analysis  0.840699
#                                         SVM                           0.643776
#                                         Random Forest                 0.955524
#                                         MLP                           0.664724
#                          MinMaxScaler   Gaussian Naive Bayes          0.601952
#                                         Logistic Regression           0.728978
#                                         Decision Tree                 0.932634
#                                         KNN                           0.719119
#                                         Linear Discriminant Analysis  0.840699
#                                         SVM                           0.647323
#                                         Random Forest                 0.955524
#                                         MLP                           0.673118
#                          StandardScaler Gaussian Naive Bayes          0.582038
#                                         Logistic Regression           0.853871
#                                         Decision Tree                 0.932649
#                                         KNN                           0.824305
#                                         Linear Discriminant Analysis  0.840699
#                                         SVM                           0.842995
#                                         Random Forest                 0.956817
#                                         MLP                           0.914250
#                          MaxAbsScaler   Gaussian Naive Bayes          0.601952
#                                         Logistic Regression           0.728978
#                                         Decision Tree                 0.934276
#                                         KNN                           0.726559
#                                         Linear Discriminant Analysis  0.840699
#                                         SVM                           0.644674
# ...                                                                        ...
# ReferenceColorSimilarity MinMaxScaler   Decision Tree                 0.652155
#                                         KNN                           0.699783
#                                         Linear Discriminant Analysis  0.736403
#                                         SVM                           0.669000
#                                         Random Forest                 0.703898
#                                         MLP                           0.672483
#                          StandardScaler Gaussian Naive Bayes          0.622267
#                                         Logistic Regression           0.773419
#                                         Decision Tree                 0.656474
#                                         KNN                           0.694850
#                                         Linear Discriminant Analysis  0.736403
#                                         SVM                           0.752514
#                                         Random Forest                 0.705536
#                                         MLP                           0.831634
#                          MaxAbsScaler   Gaussian Naive Bayes          0.622267
#                                         Logistic Regression           0.659256
#                                         Decision Tree                 0.660667
#                                         KNN                           0.691038
#                                         Linear Discriminant Analysis  0.736403
#                                         SVM                           0.662497
#                                         Random Forest                 0.707192
#                                         MLP                           0.646929
#                          RobustScaler   Gaussian Naive Bayes          0.622267
#                                         Logistic Regression           0.758665
#                                         Decision Tree                 0.652560
#                                         KNN                           0.693402
#                                         Linear Discriminant Analysis  0.736403
#                                         SVM                           0.731992
#                                         Random Forest                 0.705536
#                                         MLP                           0.797961
#
#                                                                       F1 Score
# Extrator                 Normalizador   Classificador
# AutoColorCorrelogram     não aplicado   Gaussian Naive Bayes          0.576037
#                                         Logistic Regression           0.697997
#                                         Decision Tree                 0.938125
#                                         KNN                           0.722551
#                                         Linear Discriminant Analysis  0.839315
#                                         SVM                           0.637898
#                                         Random Forest                 0.955545
#                                         MLP                           0.664071
#                          MinMaxScaler   Gaussian Naive Bayes          0.529383
#                                         Logistic Regression           0.728309
#                                         Decision Tree                 0.932677
#                                         KNN                           0.718961
#                                         Linear Discriminant Analysis  0.839315
#                                         SVM                           0.642238
#                                         Random Forest                 0.955545
#                                         MLP                           0.671605
#                          StandardScaler Gaussian Naive Bayes          0.495068
#                                         Logistic Regression           0.851550
#                                         Decision Tree                 0.932680
#                                         KNN                           0.823061
#                                         Linear Discriminant Analysis  0.839315
#                                         SVM                           0.838799
#                                         Random Forest                 0.956817
#                                         MLP                           0.913400
#                          MaxAbsScaler   Gaussian Naive Bayes          0.529383
#                                         Logistic Regression           0.728309
#                                         Decision Tree                 0.934312
#                                         KNN                           0.726399
#                                         Linear Discriminant Analysis  0.839315
#                                         SVM                           0.638892
# ...                                                                        ...
# ReferenceColorSimilarity MinMaxScaler   Decision Tree                 0.652019
#                                         KNN                           0.699743
#                                         Linear Discriminant Analysis  0.735204
#                                         SVM                           0.667210
#                                         Random Forest                 0.703652
#                                         MLP                           0.672336
#                          StandardScaler Gaussian Naive Bayes          0.622259
#                                         Logistic Regression           0.771621
#                                         Decision Tree                 0.656384
#                                         KNN                           0.694835
#                                         Linear Discriminant Analysis  0.735204
#                                         SVM                           0.751480
#                                         Random Forest                 0.705303
#                                         MLP                           0.831142
#                          MaxAbsScaler   Gaussian Naive Bayes          0.622259
#                                         Logistic Regression           0.657149
#                                         Decision Tree                 0.660552
#                                         KNN                           0.691024
#                                         Linear Discriminant Analysis  0.735204
#                                         SVM                           0.660537
#                                         Random Forest                 0.707001
#                                         MLP                           0.645250
#                          RobustScaler   Gaussian Naive Bayes          0.622259
#                                         Logistic Regression           0.756212
#                                         Decision Tree                 0.652356
#                                         KNN                           0.693385
#                                         Linear Discriminant Analysis  0.735204
#                                         SVM                           0.730985
#                                         Random Forest                 0.705303
#                                         MLP                           0.797271
#
# [320 rows x 5 columns]

# %%
perform, accur = selecao(resultados)

# %%
import pickle

pickle_out = open("resMalaria.pickle", "rb")
#pickle.dump(resultados, pickle_out)
resultados2 = pickle.load(pickle_out)
pickle_out.close()

# %%
resultados2
# Out:
#                                                                            Tempo  \
# Extrator                 Normalizador   Classificador
# AutoColorCorrelogram     não aplicado   Gaussian Naive Bayes            1.241665
#                                         Logistic Regression             0.113908
#                                         Decision Tree                   0.180844
#                                         KNN                           555.105502
#                                         Linear Discriminant Analysis    0.082135
#                                         SVM                           521.662776
#                                         Random Forest                   0.181783
#                                         MLP                             0.148893
#                          MinMaxScaler   Gaussian Naive Bayes            0.623256
#                                         Logistic Regression             0.054749
#                                         Decision Tree                   0.087913
#                                         KNN                           155.425773
#                                         Linear Discriminant Analysis    0.054885
#                                         SVM                           515.699564
#                                         Random Forest                   0.177713
#                                         MLP                             0.145565
#                          StandardScaler Gaussian Naive Bayes            0.656589
#                                         Logistic Regression             0.061374
#                                         Decision Tree                   0.087809
#                                         KNN                           739.404620
#                                         Linear Discriminant Analysis    0.054533
#                                         SVM                           415.636523
#                                         Random Forest                   0.186087
#                                         MLP                             0.151175
#                          MaxAbsScaler   Gaussian Naive Bayes            0.637148
#                                         Logistic Regression             0.058570
#                                         Decision Tree                   0.085332
#                                         KNN                           339.196182
#                                         Linear Discriminant Analysis    0.055438
#                                         SVM                           519.884832
# ...                                                                          ...
# ReferenceColorSimilarity MinMaxScaler   Decision Tree                   0.026186
#                                         KNN                             5.355303
#                                         Linear Discriminant Analysis    0.028143
#                                         SVM                            63.972426
#                                         Random Forest                   0.105063
#                                         MLP                             0.047046
#                          StandardScaler Gaussian Naive Bayes            0.054647
#                                         Logistic Regression             0.019111
#                                         Decision Tree                   0.026643
#                                         KNN                             5.343172
#                                         Linear Discriminant Analysis    0.022890
#                                         SVM                            52.710148
#                                         Random Forest                   0.094956
#                                         MLP                             0.047541
#                          MaxAbsScaler   Gaussian Naive Bayes            0.058383
#                                         Logistic Regression             0.029525
#                                         Decision Tree                   0.026323
#                                         KNN                             4.568727
#                                         Linear Discriminant Analysis    0.019047
#                                         SVM                            67.178066
#                                         Random Forest                   0.093132
#                                         MLP                             0.042323
#                          RobustScaler   Gaussian Naive Bayes            0.055871
#                                         Logistic Regression             0.019429
#                                         Decision Tree                   0.026392
#                                         KNN                             5.087428
#                                         Linear Discriminant Analysis    0.018996
#                                         SVM                            54.639582
#                                         Random Forest                   0.090995
#                                         MLP                             0.045410
#
#                                                                       Acurácia  \
# Extrator                 Normalizador   Classificador
# AutoColorCorrelogram     não aplicado   Gaussian Naive Bayes          0.628447
#                                         Logistic Regression           0.698295
#                                         Decision Tree                 0.938135
#                                         KNN                           0.722605
#                                         Linear Discriminant Analysis  0.839985
#                                         SVM                           0.642598
#                                         Random Forest                 0.955552
#                                         MLP                           0.664369
#                          MinMaxScaler   Gaussian Naive Bayes          0.598149
#                                         Logistic Regression           0.728592
#                                         Decision Tree                 0.932692
#                                         KNN                           0.718977
#                                         Linear Discriminant Analysis  0.839985
#                                         SVM                           0.646226
#                                         Random Forest                 0.955552
#                                         MLP                           0.672533
#                          StandardScaler Gaussian Naive Bayes          0.578012
#                                         Logistic Regression           0.852866
#                                         Decision Tree                 0.932692
#                                         KNN                           0.823657
#                                         Linear Discriminant Analysis  0.839985
#                                         SVM                           0.841618
#                                         Random Forest                 0.956821
#                                         MLP                           0.913643
#                          MaxAbsScaler   Gaussian Naive Bayes          0.598149
#                                         Logistic Regression           0.728592
#                                         Decision Tree                 0.934325
#                                         KNN                           0.726415
#                                         Linear Discriminant Analysis  0.839985
#                                         SVM                           0.643505
# ...                                                                        ...
# ReferenceColorSimilarity MinMaxScaler   Decision Tree                 0.652032
#                                         KNN                           0.699746
#                                         Linear Discriminant Analysis  0.735849
#                                         SVM                           0.668360
#                                         Random Forest                 0.704282
#                                         MLP                           0.672351
#                          StandardScaler Gaussian Naive Bayes          0.622279
#                                         Logistic Regression           0.772678
#                                         Decision Tree                 0.656386
#                                         KNN                           0.694848
#                                         Linear Discriminant Analysis  0.735849
#                                         SVM                           0.751996
#                                         Random Forest                 0.705914
#                                         MLP                           0.831277
#                          MaxAbsScaler   Gaussian Naive Bayes          0.622279
#                                         Logistic Regression           0.658563
#                                         Decision Tree                 0.660559
#                                         KNN                           0.691038
#                                         Linear Discriminant Analysis  0.735849
#                                         SVM                           0.661829
#                                         Random Forest                 0.707547
#                                         MLP                           0.647678
#                          RobustScaler   Gaussian Naive Bayes          0.622279
#                                         Logistic Regression           0.757801
#                                         Decision Tree                 0.652395
#                                         KNN                           0.693396
#                                         Linear Discriminant Analysis  0.735849
#                                         SVM                           0.731495
#                                         Random Forest                 0.705914
#                                         MLP                           0.797533
#
#                                                                       Precisão  \
# Extrator                 Normalizador   Classificador
# AutoColorCorrelogram     não aplicado   Gaussian Naive Bayes          0.768363
#                                         Logistic Regression           0.699702
#                                         Decision Tree                 0.938168
#                                         KNN                           0.722590
#                                         Linear Discriminant Analysis  0.847375
#                                         SVM                           0.652368
#                                         Random Forest                 0.955576
#                                         MLP                           0.665503
#                          MinMaxScaler   Gaussian Naive Bayes          0.754574
#                                         Logistic Regression           0.730230
#                                         Decision Tree                 0.932771
#                                         KNN                           0.719231
#                                         Linear Discriminant Analysis  0.847375
#                                         SVM                           0.654871
#                                         Random Forest                 0.955576
#                                         MLP                           0.675467
#                          StandardScaler Gaussian Naive Bayes          0.750890
#                                         Logistic Regression           0.868292
#                                         Decision Tree                 0.932738
#                                         KNN                           0.829498
#                                         Linear Discriminant Analysis  0.847375
#                                         SVM                           0.870868
#                                         Random Forest                 0.956817
#                                         MLP                           0.919835
#                          MaxAbsScaler   Gaussian Naive Bayes          0.754574
#                                         Logistic Regression           0.730230
#                                         Decision Tree                 0.934383
#                                         KNN                           0.726680
#                                         Linear Discriminant Analysis  0.847375
#                                         SVM                           0.653181
# ...                                                                        ...
# ReferenceColorSimilarity MinMaxScaler   Decision Tree                 0.652215
#                                         KNN                           0.699766
#                                         Linear Discriminant Analysis  0.739196
#                                         SVM                           0.671770
#                                         Random Forest                 0.705271
#                                         MLP                           0.672563
#                          StandardScaler Gaussian Naive Bayes          0.622258
#                                         Logistic Regression           0.779335
#                                         Decision Tree                 0.656494
#                                         KNN                           0.694834
#                                         Linear Discriminant Analysis  0.739196
#                                         SVM                           0.755085
#                                         Random Forest                 0.706883
#                                         MLP                           0.833071
#                          MaxAbsScaler   Gaussian Naive Bayes          0.622258
#                                         Logistic Regression           0.662343
#                                         Decision Tree                 0.660708
#                                         KNN                           0.691022
#                                         Linear Discriminant Analysis  0.739196
#                                         SVM                           0.665414
#                                         Random Forest                 0.708394
#                                         MLP                           0.650563
#                          RobustScaler   Gaussian Naive Bayes          0.622258
#                                         Logistic Regression           0.766455
#                                         Decision Tree                 0.652691
#                                         KNN                           0.693385
#                                         Linear Discriminant Analysis  0.739196
#                                         SVM                           0.734167
#                                         Random Forest                 0.706883
#                                         MLP                           0.799932
#
#                                                                         Recall  \
# Extrator                 Normalizador   Classificador
# AutoColorCorrelogram     não aplicado   Gaussian Naive Bayes          0.631952
#                                         Logistic Regression           0.698669
#                                         Decision Tree                 0.938099
#                                         KNN                           0.722538
#                                         Linear Discriminant Analysis  0.840699
#                                         SVM                           0.643776
#                                         Random Forest                 0.955524
#                                         MLP                           0.664724
#                          MinMaxScaler   Gaussian Naive Bayes          0.601952
#                                         Logistic Regression           0.728978
#                                         Decision Tree                 0.932634
#                                         KNN                           0.719119
#                                         Linear Discriminant Analysis  0.840699
#                                         SVM                           0.647323
#                                         Random Forest                 0.955524
#                                         MLP                           0.673118
#                          StandardScaler Gaussian Naive Bayes          0.582038
#                                         Logistic Regression           0.853871
#                                         Decision Tree                 0.932649
#                                         KNN                           0.824305
#                                         Linear Discriminant Analysis  0.840699
#                                         SVM                           0.842995
#                                         Random Forest                 0.956817
#                                         MLP                           0.914250
#                          MaxAbsScaler   Gaussian Naive Bayes          0.601952
#                                         Logistic Regression           0.728978
#                                         Decision Tree                 0.934276
#                                         KNN                           0.726559
#                                         Linear Discriminant Analysis  0.840699
#                                         SVM                           0.644674
# ...                                                                        ...
# ReferenceColorSimilarity MinMaxScaler   Decision Tree                 0.652155
#                                         KNN                           0.699783
#                                         Linear Discriminant Analysis  0.736403
#                                         SVM                           0.669000
#                                         Random Forest                 0.703898
#                                         MLP                           0.672483
#                          StandardScaler Gaussian Naive Bayes          0.622267
#                                         Logistic Regression           0.773419
#                                         Decision Tree                 0.656474
#                                         KNN                           0.694850
#                                         Linear Discriminant Analysis  0.736403
#                                         SVM                           0.752514
#                                         Random Forest                 0.705536
#                                         MLP                           0.831634
#                          MaxAbsScaler   Gaussian Naive Bayes          0.622267
#                                         Logistic Regression           0.659256
#                                         Decision Tree                 0.660667
#                                         KNN                           0.691038
#                                         Linear Discriminant Analysis  0.736403
#                                         SVM                           0.662497
#                                         Random Forest                 0.707192
#                                         MLP                           0.646929
#                          RobustScaler   Gaussian Naive Bayes          0.622267
#                                         Logistic Regression           0.758665
#                                         Decision Tree                 0.652560
#                                         KNN                           0.693402
#                                         Linear Discriminant Analysis  0.736403
#                                         SVM                           0.731992
#                                         Random Forest                 0.705536
#                                         MLP                           0.797961
#
#                                                                       F1 Score
# Extrator                 Normalizador   Classificador
# AutoColorCorrelogram     não aplicado   Gaussian Naive Bayes          0.576037
#                                         Logistic Regression           0.697997
#                                         Decision Tree                 0.938125
#                                         KNN                           0.722551
#                                         Linear Discriminant Analysis  0.839315
#                                         SVM                           0.637898
#                                         Random Forest                 0.955545
#                                         MLP                           0.664071
#                          MinMaxScaler   Gaussian Naive Bayes          0.529383
#                                         Logistic Regression           0.728309
#                                         Decision Tree                 0.932677
#                                         KNN                           0.718961
#                                         Linear Discriminant Analysis  0.839315
#                                         SVM                           0.642238
#                                         Random Forest                 0.955545
#                                         MLP                           0.671605
#                          StandardScaler Gaussian Naive Bayes          0.495068
#                                         Logistic Regression           0.851550
#                                         Decision Tree                 0.932680
#                                         KNN                           0.823061
#                                         Linear Discriminant Analysis  0.839315
#                                         SVM                           0.838799
#                                         Random Forest                 0.956817
#                                         MLP                           0.913400
#                          MaxAbsScaler   Gaussian Naive Bayes          0.529383
#                                         Logistic Regression           0.728309
#                                         Decision Tree                 0.934312
#                                         KNN                           0.726399
#                                         Linear Discriminant Analysis  0.839315
#                                         SVM                           0.638892
# ...                                                                        ...
# ReferenceColorSimilarity MinMaxScaler   Decision Tree                 0.652019
#                                         KNN                           0.699743
#                                         Linear Discriminant Analysis  0.735204
#                                         SVM                           0.667210
#                                         Random Forest                 0.703652
#                                         MLP                           0.672336
#                          StandardScaler Gaussian Naive Bayes          0.622259
#                                         Logistic Regression           0.771621
#                                         Decision Tree                 0.656384
#                                         KNN                           0.694835
#                                         Linear Discriminant Analysis  0.735204
#                                         SVM                           0.751480
#                                         Random Forest                 0.705303
#                                         MLP                           0.831142
#                          MaxAbsScaler   Gaussian Naive Bayes          0.622259
#                                         Logistic Regression           0.657149
#                                         Decision Tree                 0.660552
#                                         KNN                           0.691024
#                                         Linear Discriminant Analysis  0.735204
#                                         SVM                           0.660537
#                                         Random Forest                 0.707001
#                                         MLP                           0.645250
#                          RobustScaler   Gaussian Naive Bayes          0.622259
#                                         Logistic Regression           0.756212
#                                         Decision Tree                 0.652356
#                                         KNN                           0.693385
#                                         Linear Discriminant Analysis  0.735204
#                                         SVM                           0.730985
#                                         Random Forest                 0.705303
#                                         MLP                           0.797271
#
# [320 rows x 5 columns]

# %%
perform
# Out:
#                                          Tempo  Acurácia  Precisão    Recall  \
# GCH RobustScaler Logistic Regression  0.018512  0.884615   0.89948  0.885568
#
#                                       F1 Score
# GCH RobustScaler Logistic Regression  0.883704

# %%
accur
# Out:
#                                    Tempo  Acurácia  Precisão    Recall  \
# GCH RobustScaler Random Forest  0.073414  0.960994  0.961004  0.960978
#
#                                 F1 Score
# GCH RobustScaler Random Forest  0.960989
